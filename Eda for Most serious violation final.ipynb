# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

data = pd.read_csv("by most serious violation1.csv")
data.head()
# Out:
#                     Most serious violation  2014  2015  2016  2017  2018  \
# 0    Homicide and other related violations     2     1     1     2     2
# 1             Assault, level 3, aggravated     5     3     3     9     9
# 2  Assault, level 2, weapon or bodily harm    46    66    70    92   103
# 3                         Assault, level 1   131   137   195   215   233
# 4                            Total robbery     9    10     8    20    18
#
#    2019  2020 2021 2022  ...  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0     2     8   13   23  ...          NaN          NaN          NaN
# 1     2     9    8   10  ...          NaN          NaN          NaN
# 2   103   156  215  230  ...          NaN          NaN          NaN
# 3   291   353  429  504  ...          NaN          NaN          NaN
# 4     9    13   20   26  ...          NaN          NaN          NaN
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# ...

# %%
# Check for missing values
missing_values = data.isnull().sum()
print("Missing values:\n", missing_values)

# Remove duplicates if any
data = data.drop_duplicates()
# Out:
# Missing values:
#  Most serious violation     0
# 2014                       0
# 2015                       0
# 2016                       0
# 2017                       0
# 2018                       0
# 2019                       0
# 2020                       0
# 2021                       0
# 2022                       0
# Unnamed: 10               15
# Unnamed: 11               15
# Unnamed: 12               15
# Unnamed: 13               15
# Unnamed: 14               15
# Unnamed: 15               15
# Unnamed: 16               15
# Unnamed: 17               15
# Unnamed: 18               15
# Unnamed: 19               15
# Unnamed: 20               15
# Unnamed: 21               15
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

data = pd.read_csv("by most serious violation1.csv")
# Summary statistics
summary = data.describe()
print("Summary Statistics:\n\n", summary)
# Out:
# Summary Statistics:
#
#               2014        2015        2016        2017        2018        2019  \
# count   15.000000   15.000000   15.000000   15.000000   15.000000   15.000000
# mean    78.000000   84.800000   90.600000  137.866667  121.133333  130.066667
# std    129.791041  139.352687  135.860117  234.925176  181.130918  199.949803
# min      2.000000    1.000000    1.000000    2.000000    2.000000    2.000000
# 25%     15.000000   14.000000   16.500000   26.500000   29.000000   16.500000
# 50%     40.000000   50.000000   52.000000   74.000000   73.000000   73.000000
# 75%     72.000000   64.500000   76.000000  107.000000  104.500000  105.500000
# max    523.000000  561.000000  535.000000  936.000000  715.000000  770.000000
#
#              2020  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# count   15.000000          0.0          0.0          0.0          0.0
# mean   176.400000          NaN          NaN          NaN          NaN
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

data = pd.read_csv("by most serious violation1.csv")
data.head()
# Assuming you have your dataset loaded as 'data'

# Calculate the sum for each row (excluding the 'Most serious violation' column)
data['Row Sum'] = data.iloc[:, 1:].sum(axis=1)

# Create a pie chart for the row sums
plt.figure(figsize=(10, 10))
plt.pie(data['Row Sum'], labels=data['Most serious violation'], autopct='%1.1f%%', startangle=140)
plt.title('Sum of Violations Over the Years (2014-2022)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

data = pd.read_csv("by most serious violation1.csv")
data.head()

# Assuming you have your dataset loaded as 'data'

# Calculate the sum for each row (excluding the 'Most serious violation' column)
data['Row Sum'] = data.iloc[:, 1:].sum(axis=1)

# Sort the data by the sum of violations in descending order
data = data.sort_values(by='Row Sum', ascending=False)

# Create a bar chart for the row sums
plt.figure(figsize=(12, 6))
plt.bar(data['Most serious violation'], data['Row Sum'])
plt.xlabel('Category')
plt.ylabel('Sum of Violations (2014-2022)')
plt.title('Sum of Violations by Category Over the Years (2014-2022)')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()
