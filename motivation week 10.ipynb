# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')


data = {
    'Type of motivation': ['Race or ethnicity', 'Religion', 'Sexual orientation', 'Language', 'Disability', 'Sex and gender', 'Age', 'Other similar factor', 'Unknown motivation'],
    2014: [611, 429, 155, 12, 10, 22, 6, 10, 23],
    2015: [641, 469, 141, 18, 8, 12, 4, 27, 25],
    2016: [666, 460, 176, 13, 11, 24, 5, 44, 19],
    2017: [878, 842, 204, 23, 14, 32, 4, 35, 32],
    2018: [793, 657, 186, 14, 9, 54, 9, 48, 22],
    2019: [884, 613, 265, 25, 3, 56, 8, 73, 39],
    2020: [1619, 530, 258, 37, 8, 49, 5, 58, 39],
    2021: [1745, 886, 438, 33, 16, 60, 14, 101, 81],
    2022: [1950, 750, 491, 59, 15, 89, 7, 98, 117]
}

df = pd.DataFrame(data)
df.head()

# Data Inspection
print("Data Information:")
print(df.info())
print("\nData Preview:")
print(df.head())

# Summary Statistics
print("\nSummary Statistics:")
print(df.describe())

# 1. Line plot to show trends over the years for different types of motivations
plt.figure(figsize=(12, 6))
for motivation in df.columns[1:]:
    plt.plot(df['Type of motivation'], df[motivation], marker='o', label=motivation)
plt.title('Trends of Hate Crimes by Type of Motivation (2014-2022)')
plt.xlabel('Type of Motivation')
plt.ylabel('Number of Hate Crimes')
plt.xticks(rotation=90)
plt.legend()
plt.grid()
plt.show()


# 2. Visualize the data using seaborn
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")
sns.lineplot(data=df.melt(id_vars='Type of motivation', var_name='Year', value_name='Hate Crimes'), x='Year', y='Hate Crimes', hue='Type of motivation')
plt.title("Hate Crimes by Type of Motivation Over the Years")
plt.xticks(rotation=45)
plt.xlabel("Year")
plt.ylabel("Number of Hate Crimes")
plt.legend(title="Motivation")
plt.show()

# 3. Compare hate crimes across motivations in a specific year (e.g., 2022)
year_2022 = df[['Type of motivation', 2022]].sort_values(by=2022, ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(data=year_2022, x=2022, y='Type of motivation', palette="viridis")
plt.title("Hate Crimes by Type of Motivation in 2022")
plt.xlabel("Number of Hate Crimes")
plt.ylabel("Motivation")
plt.show()


# 5. Identify outliers, if any, using box plots
plt.figure(figsize=(12, 6))
sns.boxplot(data=df.drop(columns='Type of motivation'), palette="Set3")
plt.title("Box Plot of Hate Crimes by Year")
plt.ylabel("Number of Hate Crimes")
plt.xticks(rotation=45)
plt.show()

# hate crimes over years
plt.figure(figsize=(12, 6))
for year in range(2014, 2023):
    sns.kdeplot(df[year], label=year)
plt.title("Distribution of Hate Crimes Over the Years")
plt.xlabel("Number of Hate Crimes")
plt.legend(title="Year")
plt.show()




#pairwise scatter plots
sns.pairplot(data=df[['Type of motivation', 2014, 2017, 2022]], hue='Type of motivation')
plt.suptitle("Pairwise Scatter Plots of Hate Crimes by Motivation")
plt.show()
# Out:
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Type of motivation  9 non-null      object
#  1   2014                9 non-null      int64
#  2   2015                9 non-null      int64
#  3   2016                9 non-null      int64
#  4   2017                9 non-null      int64
#  5   2018                9 non-null      int64
#  6   2019                9 non-null      int64
#  7   2020                9 non-null      int64
#  8   2021                9 non-null      int64
#  9   2022                9 non-null      int64
# dtypes: int64(9), object(1)
# memory usage: 848.0+ bytes
# None
#
# Data Preview:
#    Type of motivation  2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0   Race or ethnicity   611   641   666   878   793   884  1619  1745  1950
# ...

# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame from the provided data
data = {
    'Type of motivation': ['Race or ethnicity', 'Religion', 'Sexual orientation', 'Language', 'Disability', 'Sex and gender', 'Age', 'Other similar factor', 'Unknown motivation'],
    2014: [611, 429, 155, 12, 10, 22, 6, 10, 23],
    2015: [641, 469, 141, 18, 8, 12, 4, 27, 25],
    2016: [666, 460, 176, 13, 11, 24, 5, 44, 19],
    2017: [878, 842, 204, 23, 14, 32, 4, 35, 32],
    2018: [793, 657, 186, 14, 9, 54, 9, 48, 22],
    2019: [884, 613, 265, 25, 3, 56, 8, 73, 39],
    2020: [1619, 530, 258, 37, 8, 49, 5, 58, 39],
    2021: [1745, 886, 438, 33, 16, 60, 14, 101, 81],
    2022: [1950, 750, 491, 59, 15, 89, 7, 98, 117]
}

df = pd.DataFrame(data)

# 1. Basic Summary Statistics
summary = df.describe()#pairwise scatter plots
sns.pairplot(data=df[['Type of motivation', 2014, 2017, 2022]], hue='Type of motivation')
plt.suptitle("Pairwise Scatter Plots of Hate Crimes by Motivation")
plt.show()

# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame from the provided data
data = {
    'Type of motivation': ['Race or ethnicity', 'Religion', 'Sexual orientation', 'Language', 'Disability', 'Sex and gender', 'Age', 'Other similar factor', 'Unknown motivation'],
    2014: [611, 429, 155, 12, 10, 22, 6, 10, 23],
    2015: [641, 469, 141, 18, 8, 12, 4, 27, 25],
    2016: [666, 460, 176, 13, 11, 24, 5, 44, 19],
    2017: [878, 842, 204, 23, 14, 32, 4, 35, 32],
    2018: [793, 657, 186, 14, 9, 54, 9, 48, 22],
    2019: [884, 613, 265, 25, 3, 56, 8, 73, 39],
    2020: [1619, 530, 258, 37, 8, 49, 5, 58, 39],
    2021: [1745, 886, 438, 33, 16, 60, 14, 101, 81],
    2022: [1950, 750, 491, 59, 15, 89, 7, 98, 117]
}

df = pd.DataFrame(data)

# 1. Basic Summary Statistics
summary = df.describe()
# hate crimes over years
plt.figure(figsize=(12, 6))
for year in range(2014, 2023):
    sns.kdeplot(df[year], label=year)
plt.title("Distribution of Hate Crimes Over the Years")
plt.xlabel("Number of Hate Crimes")
plt.legend(title="Year")
plt.show()

# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame from the provided data
data = {
    'Type of motivation': ['Race or ethnicity', 'Religion', 'Sexual orientation', 'Language', 'Disability', 'Sex and gender', 'Age', 'Other similar factor', 'Unknown motivation'],
    2014: [611, 429, 155, 12, 10, 22, 6, 10, 23],
    2015: [641, 469, 141, 18, 8, 12, 4, 27, 25],
    2016: [666, 460, 176, 13, 11, 24, 5, 44, 19],
    2017: [878, 842, 204, 23, 14, 32, 4, 35, 32],
    2018: [793, 657, 186, 14, 9, 54, 9, 48, 22],
    2019: [884, 613, 265, 25, 3, 56, 8, 73, 39],
    2020: [1619, 530, 258, 37, 8, 49, 5, 58, 39],
    2021: [1745, 886, 438, 33, 16, 60, 14, 101, 81],
    2022: [1950, 750, 491, 59, 15, 89, 7, 98, 117]
}

df = pd.DataFrame(data)

# 1. Basic Summary Statistics
summary = df.describe()
# 3. Compare hate crimes across motivations in a specific year (e.g., 2022)
year_2022 = df[['Type of motivation', 2022]].sort_values(by=2022, ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(data=year_2022, x=2022, y='Type of motivation', palette="viridis")
plt.title("Hate Crimes by Type of Motivation in 2022")
plt.xlabel("Number of Hate Crimes")
plt.ylabel("Motivation")
plt.show()

# %%
# Import the necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt


# Create a DataFrame from the provided data
data = {
    'Type of motivation': ['Race or ethnicity', 'Religion', 'Sexual orientation', 'Language', 'Disability', 'Sex and gender', 'Age', 'Other similar factor', 'Unknown motivation'],
    2014: [611, 429, 155, 12, 10, 22, 6, 10, 23],
    2015: [641, 469, 141, 18, 8, 12, 4, 27, 25],
    2016: [666, 460, 176, 13, 11, 24, 5, 44, 19],
    2017: [878, 842, 204, 23, 14, 32, 4, 35, 32],
    2018: [793, 657, 186, 14, 9, 54, 9, 48, 22],
    2019: [884, 613, 265, 25, 3, 56, 8, 73, 39],
    2020: [1619, 530, 258, 37, 8, 49, 5, 58, 39],
    2021: [1745, 886, 438, 33, 16, 60, 14, 101, 81],
    2022: [1950, 750, 491, 59, 15, 89, 7, 98, 117],
    'Total police-reported hate crime': [1295,1362, 1409,2073,1817,1951,2646,3355,3576]

}

df = pd.DataFrame(data)

df = pd.DataFrame(data)
df.set_index('Type of motivation', inplace=True)

# Prepare the data
X = df.drop('Total police-reported hate crime', axis=1)  # Features
y = df['Total police-reported hate crime']  # Target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred, squared=False))

# Plot the predictions against the actual values
plt.scatter(X_test.index, y_test, color='black', label='Actual values')
plt.plot(X_test.index, y_pred, color='blue', linewidth=3, label='Predicted values')
plt.xticks(rotation=45)
plt.xlabel('Type of motivation')
plt.ylabel('Total police-reported hate crime')
plt.legend()
plt.show()





import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import matplotlib.pyplot as plt

# ... (the data loading and preparation steps remain the same)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create a Random Forest Regressor model
model_rf = RandomForestRegressor(n_estimators=100, random_state=0)

# Train the model
model_rf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = model_rf.predict(X_test)

# Evaluate the Random Forest Regressor model
print('Mean Absolute Error (Random Forest):', metrics.mean_absolute_error(y_test, y_pred_rf))
print('Mean Squared Error (Random Forest):', metrics.mean_squared_error(y_test, y_pred_rf))
print('Root Mean Squared Error (Random Forest):', metrics.mean_squared_error(y_test, y_pred_rf, squared=False))

# Plot the predictions against the actual values for Random Forest Regressor
plt.scatter(X_test.index, y_test, color='black', label='Actual values')
plt.plot(X_test.index, y_pred_rf, color='green', linewidth=3, label='Random Forest Predictions')
plt.xticks(rotation=45)
plt.xlabel('Type of motivation')
plt.ylabel('Total police-reported hate crime')
plt.legend()
plt.show()


# ... (previous code)
# Out:
# Mean Absolute Error: 3794.1361797392256
# Mean Squared Error: 20684753.458893307
# Root Mean Squared Error: 4548.049412538666
# Mean Absolute Error (Random Forest): 1043.115
# Mean Squared Error (Random Forest): 1113632.9338500001
# Root Mean Squared Error (Random Forest): 1055.2880809759959
